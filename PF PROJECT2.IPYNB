# %%
import pandas as pd

# %%
import matplotlib as plt
df=pd.read_csv("top universities.csv")

# %%
df
#for showing data
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank
# 0             3677
# 1             4919
# ...

# %%
df.head()
#showing first five rows
# Out:
#                                           University  Country     City  \
# 0  Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1           Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2          École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                      École Nationale Polytechnique  Algeria  Algiers
# 4       Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
#
#    Global Rank
# 0         3677
# 1         4919
# 2         6297
# 3         6411
# 4         6421

# %%
df.tail()
#showing last five rows
# Out:
#                                               University  Country     City  \
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank
# 12708        11518
# 12709        11549
# 12710        11572
# 12711        11630
# 12712        12698

# %%
df.sample()
#randomly sample rows
# Out:
#                              University    Country    City  Global Rank
# 7869  Kauno technologijos universitetas  Lithuania  Kaunas         1163

# %%
print(df.shape)
# Out:
# (12713, 4)

# %%
df.rename(columns={"Global Rank":"Global"})
#is used in Pandas to rename columns in the DataFrame df.
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global
# 0        3677
# 1        4919
# 2        6297
# ...

# %%
pd.set_option=("display.max_rows",None)
df
#This will display all rows when you print or display the DataFrame (df in this case). By default, Pandas limits the number of rows shown to avoid overwhelming the output.
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank
# 0             3677
# 1             4919
# ...

# %%
df.info()
#The df.info() method in Pandas is used to display a concise summary of a DataFrame.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12713 entries, 0 to 12712
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   University   12713 non-null  object
#  1   Country      12713 non-null  object
#  2   City         12713 non-null  object
#  3   Global Rank  12713 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 397.4+ KB

# %%
df.describe()
#The df.describe() method in Pandas provides a summary of statistics for the numeric columns in a DataFrame.
# Out:
#         Global Rank
# count  12713.000000
# mean    6369.518760
# std     3665.469943
# min        1.000000
# 25%     3199.000000
# 50%     6373.000000
# 75%     9540.000000
# max    12721.000000

# %%
df.describe(include = "all")
#When you use df.describe(include="all"), it provides a summary of both numeric and non-numeric (categorical) columns in the DataFrame.
# Out:
#                         University Country      City   Global Rank
# count                        12713   12713     12713  12713.000000
# unique                       12528     145      1157           NaN
# top     Duksung Women’s University     Usa  New York           NaN
# freq                             2    1724       150           NaN
# mean                           NaN     NaN       NaN   6369.518760
# std                            NaN     NaN       NaN   3665.469943
# min                            NaN     NaN       NaN      1.000000
# 25%                            NaN     NaN       NaN   3199.000000
# 50%                            NaN     NaN       NaN   6373.000000
# 75%                            NaN     NaN       NaN   9540.000000
# max                            NaN     NaN       NaN  12721.000000

# %%
a=df["University"]
a
#he variable a will now hold the Series corresponding to the "University" column in the DataFrame.
# Out:
# 0        Université des Sciences et de la Technologie H...
# 1                 Université Benyoucef Benkhedda d’Alger 1
# 2                École Nationale Supérieure d’Informatique
# 3                            École Nationale Polytechnique
# 4             Université Abou el Kacem Saâdallah d’Alger 2
#                                ...
# 12708    Facultad de Teologa del Uruguay Mons. Mariano ...
# 12709                        Politécnico de Punta del Este
# 12710    Instituto Universitario de Docencia, Investiga...
# 12711            Instituto Metodista Universitario Crandon
# 12712    Instituto Universitario de Postgrado en Psicoa...
# Name: University, Length: 12713, dtype: object

# %%
b= df[["University","Global Rank"]]
b
#he variable a will now hold the Series corresponding to the "University" or global rank column in the DataFrame.
# Out:
#                                               University  Global Rank
# 0      Université des Sciences et de la Technologie H...         3677
# 1               Université Benyoucef Benkhedda d’Alger 1         4919
# 2              École Nationale Supérieure d’Informatique         6297
# 3                          École Nationale Polytechnique         6411
# 4           Université Abou el Kacem Saâdallah d’Alger 2         6421
# ...                                                  ...          ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...        11518
# 12709                      Politécnico de Punta del Este        11549
# 12710  Instituto Universitario de Docencia, Investiga...        11572
# 12711          Instituto Metodista Universitario Crandon        11630
# 12712  Instituto Universitario de Postgrado en Psicoa...        12698
#
# [12713 rows x 2 columns]

# %%
df["Global Rank"].mean()
# Out:
# 6369.518760324077

# %%
df["Global Rank"].median
# Out:
# <bound method Series.median of 0         3677
# 1         4919
# 2         6297
# 3         6411
# 4         6421
#          ...
# 12708    11518
# 12709    11549
# 12710    11572
# 12711    11630
# 12712    12698
# Name: Global Rank, Length: 12713, dtype: int64>

# %%
df["Global Rank"].mode
# Out:
# <bound method Series.mode of 0         3677
# 1         4919
# 2         6297
# 3         6411
# 4         6421
#          ...
# 12708    11518
# 12709    11549
# 12710    11572
# 12711    11630
# 12712    12698
# Name: Global Rank, Length: 12713, dtype: int64>

# %%
df["University"].value_counts
#is used to get the count of each unique value in the "University" column of your DataFrame
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Université des Sciences et de la Technologie H...
# 1                 Université Benyoucef Benkhedda d’Alger 1
# 2                École Nationale Supérieure d’Informatique
# 3                            École Nationale Polytechnique
# 4             Université Abou el Kacem Saâdallah d’Alger 2
#                                ...
# 12708    Facultad de Teologa del Uruguay Mons. Mariano ...
# 12709                        Politécnico de Punta del Este
# 12710    Instituto Universitario de Docencia, Investiga...
# 12711            Instituto Metodista Universitario Crandon
# 12712    Instituto Universitario de Postgrado en Psicoa...
# Name: University, Length: 12713, dtype: object>

# %%
df["Country"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
df["Global Rank"].plot(kind="line")
# Out:
# <Axes: >

# %%
df["Country"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Country"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Global Rank"].value_counts().plot(kind="line", color='red')
# Out:
# <Axes: xlabel='Global Rank'>

# %%
df["Country"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Country'>

# %%
df.plot(color='black')
# Out:
# <Axes: >

# %%
df["Global Rank"].std()
# is used to calculate the standard deviation of the values
# Out:
# 3665.469942896731

# %%
df.isnull()
# Out:
#        University  Country   City  Global Rank
# 0           False    False  False        False
# 1           False    False  False        False
# 2           False    False  False        False
# 3           False    False  False        False
# 4           False    False  False        False
# ...           ...      ...    ...          ...
# 12708       False    False  False        False
# 12709       False    False  False        False
# 12710       False    False  False        False
# 12711       False    False  False        False
# 12712       False    False  False        False
#
# [12713 rows x 4 columns]

# %%
df.isnull().sum()
#is used to count the number of missing values (null values) in each column
# Out:
# University     0
# Country        0
# City           0
# Global Rank    0
# dtype: int64

# %%
df[df["University"].isnull()]
#s used to filter the rows in the DataFrame df where the values in the "university" column are missing (i.e., NaN or null).
# Out:
# Empty DataFrame
# Columns: [University, Country, City, Global Rank]
# Index: []

# %%
df["global world"]=df["Global Rank"].fillna(df["Global Rank"].mean())
#s used to fill missing values (NaN values) in the "Global Rank" column with the mean of the "Global Rank" column and create a new column "global world" with these updated values.

# %%
df[df["Global Rank"].isnull()]
#new couloumn created
# Out:
# Empty DataFrame
# Columns: [University, Country, City, Global Rank, global world]
# Index: []

# %%
df.loc[[2,5,8,12]]
#The code df.loc[[2,5,8,12]] in Pandas is used to select specific rows from the DataFrame df by their index labels.
# Out:
#                                            University  Country     City  \
# 2           École Nationale Supérieure d’Informatique  Algeria  Algiers
# 5        Université Brahim Soltane Chaibout d’Alger 3  Algeria  Algiers
# 8   École Nationale d’Administration Moulay Ahmed ...  Algeria  Algiers
# 12  École Nationale Supérieure en Statistique et e...  Algeria  Algiers
#
#     Global Rank  global world
# 2          6297          6297
# 5          6746          6746
# 8          8453          8453
# 12         9259          9259

# %%
df.iloc[[2,4]]
#The code df.iloc[[2,4]] is used to select specific rows by integer-based index positions from the DataFrame
# Out:
#                                      University  Country     City  \
# 2     École Nationale Supérieure d’Informatique  Algeria  Algiers
# 4  Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
#
#    Global Rank  global world
# 2         6297          6297
# 4         6421          6421

# %%
df.groupby("University").describe()
#The code df.groupby("University").describe() is used to group the DataFrame df by the "University" column, and then calculate descriptive statistics for each numerical column within each university group.
# Out:
#                              Global Rank                                 \
#                                    count     mean std      min      25%
# University
# A.T. Still University                1.0   2490.0 NaN   2490.0   2490.0
# ABM University College               1.0   9896.0 NaN   9896.0   9896.0
# ADA University                       1.0   3731.0 NaN   3731.0   3731.0
# AKS University                       1.0  10418.0 NaN  10418.0  10418.0
# AMA Computer University              1.0   8613.0 NaN   8613.0   8613.0
# ...                                  ...      ...  ..      ...      ...
# Šiauliu Universitetas                1.0   3647.0 NaN   3647.0   3647.0
# Šiauliu valstybine kolegija          1.0   7937.0 NaN   7937.0   7937.0
# Šiaures Lietuvos kolegija            1.0   8731.0 NaN   8731.0   8731.0
# Škoda Auto Vysoká kola               1.0   6110.0 NaN   6110.0   6110.0
# Žilinská univerzita v Žiline         1.0   3048.0 NaN   3048.0   3048.0
#
# ...

# %%
print(df.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12708    False
# 12709    False
# 12710    False
# 12711    False
# 12712    False
# Length: 12713, dtype: bool

# %%
df.fillna(55)
#The code df.fillna(55) is used to fill all missing values (i.e., NaN values) in the DataFrame df with the value 55.
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank  global world
# 0             3677          3677
# ...

# %%
df.dropna()
#The code df.dropna() is used to remove rows from the DataFrame df that contain missing values (NaN or None values).
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank  global world
# 0             3677          3677
# ...

# %%
df[2:5]
#slicing
# Out:
#                                      University  Country     City  \
# 2     École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                 École Nationale Polytechnique  Algeria  Algiers
# 4  Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
#
#    Global Rank  global world
# 2         6297          6297
# 3         6411          6411
# 4         6421          6421

# %%
df[1:7:2]
#slicing
# Out:
#                                      University  Country     City  \
# 1      Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 3                 École Nationale Polytechnique  Algeria  Algiers
# 5  Université Brahim Soltane Chaibout d’Alger 3  Algeria  Algiers
#
#    Global Rank  global world
# 1         4919          4919
# 3         6411          6411
# 5         6746          6746

# %%
kind='bar'

# %%
df.columns
# Out:
# Index(['University', 'Country', 'City', 'Global Rank', 'global world'], dtype='object')

# %%
df.dtypes
# Out:
# University      object
# Country         object
# City            object
# Global Rank      int64
# global world     int64
# dtype: object

# %%
x = df['University'].fillna(800)

# %%
df.notnull()
# Out:
#        University  Country  City  Global Rank  global world
# 0            True     True  True         True          True
# 1            True     True  True         True          True
# 2            True     True  True         True          True
# 3            True     True  True         True          True
# 4            True     True  True         True          True
# ...           ...      ...   ...          ...           ...
# 12708        True     True  True         True          True
# 12709        True     True  True         True          True
# 12710        True     True  True         True          True
# 12711        True     True  True         True          True
# 12712        True     True  True         True          True
#
# [12713 rows x 5 columns]
